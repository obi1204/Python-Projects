# %% [markdown]
# <a href="https://colab.research.google.com/github/obi1204/Python-Courses-and-Projects/blob/main/Comparing_Amazon_and_Gamestop_High_stock_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

#import amazon historical stock dataset
amazon = pd.read_csv("Amazon.csv")

# %%
amazon
# Out:
#             Date         Open         High          Low        Close  \
# 0     1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1     1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2     1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3     1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4     1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...          ...          ...          ...          ...          ...
# 6150  2021-10-21  3414.250000  3440.280029  3403.000000  3435.010010
# 6151  2021-10-22  3421.000000  3429.840088  3331.300049  3335.550049
# 6152  2021-10-25  3335.000000  3347.800049  3297.699951  3320.370117
# 6153  2021-10-26  3349.510010  3416.120117  3343.979980  3376.070068
# 6154  2021-10-27  3388.000000  3412.000000  3371.453369  3396.189941
#
#         Adj Close    Volume
# 0        1.958333  72156000
# 1        1.729167  14700000
# 2        1.708333   6106800
# ...

# %%
#data in descending order
desc = amazon.sort_values("High")
desc
# Out:
#             Date         Open         High          Low        Close  \
# 5     1997-05-22     1.437500     1.447917     1.312500     1.395833
# 13    1997-06-04     1.479167     1.489583     1.395833     1.416667
# 10    1997-05-30     1.500000     1.510417     1.479167     1.500000
# 30    1997-06-27     1.515625     1.515625     1.479167     1.489583
# 29    1997-06-26     1.520833     1.520833     1.505208     1.510417
# ...          ...          ...          ...          ...          ...
# 6075  2021-07-07  3717.379883  3734.199951  3678.909912  3696.580078
# 6077  2021-07-09  3722.520020  3748.000000  3693.399902  3719.340088
# 6078  2021-07-12  3744.000000  3757.290039  3696.790039  3718.550049
# 6076  2021-07-08  3643.560059  3759.989990  3621.120117  3731.409912
# 6079  2021-07-13  3702.100098  3773.080078  3671.320068  3677.360107
#
#         Adj Close    Volume
# 5        1.395833  11776800
# 13       1.416667   3080400
# 10       1.500000   2594400
# ...

# %%
#frequency of high prices
desc["High"].plot.hist();

# %%
#converting date column to datetime
amazon["Date"] = pd.to_datetime(amazon['Date'], infer_datetime_format=True)

# %%
amazon.plot.scatter(x = "High", y = "Date");

# %%
#statistical info of High column
amazon["High"].describe()
# Out:
# count    6155.000000
# mean      526.216132
# std       865.821041
# min         1.447917
# 25%        39.514999
# 50%        94.190002
# 75%       535.304993
# max      3773.080078
# Name: High, dtype: float64

# %%
#importing gamespot data
gstop = pd.read_csv("GME_stock.csv")
gstop
# Out:
#             date  open_price  high_price   low_price  close_price  \
# 0     2021-01-28  265.000000  483.000000  112.250000   193.600006
# 1     2021-01-27  354.829987  380.000000  249.000000   347.510010
# 2     2021-01-26   88.559998  150.000000   80.199997   147.979996
# 3     2021-01-25   96.730003  159.179993   61.130001    76.790001
# 4     2021-01-22   42.590000   76.760002   42.320000    65.010002
# ...          ...         ...         ...         ...          ...
# 4768  2002-02-20    9.600000    9.875000    9.525000     9.875000
# 4769  2002-02-19    9.900000    9.900000    9.375000     9.550000
# 4770  2002-02-15   10.000000   10.025000    9.850000     9.950000
# 4771  2002-02-14   10.175000   10.195000    9.925000    10.000000
# 4772  2002-02-13    9.625000   10.060000    9.525000    10.050000
#
#            volume  adjclose_price
# 0      58815800.0      193.600006
# 1      93396700.0      347.510010
# 2     178588000.0      147.979996
# ...

# %%
gdesc = gstop.sort_values("date")
gdesc
# Out:
#             date  open_price  high_price   low_price  close_price  \
# 4772  2002-02-13    9.625000   10.060000    9.525000    10.050000
# 4771  2002-02-14   10.175000   10.195000    9.925000    10.000000
# 4770  2002-02-15   10.000000   10.025000    9.850000     9.950000
# 4769  2002-02-19    9.900000    9.900000    9.375000     9.550000
# 4768  2002-02-20    9.600000    9.875000    9.525000     9.875000
# ...          ...         ...         ...         ...          ...
# 4     2021-01-22   42.590000   76.760002   42.320000    65.010002
# 3     2021-01-25   96.730003  159.179993   61.130001    76.790001
# 2     2021-01-26   88.559998  150.000000   80.199997   147.979996
# 1     2021-01-27  354.829987  380.000000  249.000000   347.510010
# 0     2021-01-28  265.000000  483.000000  112.250000   193.600006
#
#            volume  adjclose_price
# 4772   19054000.0        6.766666
# 4771    2755400.0        6.733003
# 4770    2097400.0        6.699336
# ...

# %%
gstop['date'] = pd.to_datetime(gstop['date'], infer_datetime_format=True)

# %%
#comparing Gamestop and Amazon High prices
y1, y2= amazon["High"], gstop["high_price"]
x1, x2 = amazon['Date'], gstop['date']

fig, ax = plt.subplots()
ax.plot(x1,y1, x2,y2)

plt.show;
